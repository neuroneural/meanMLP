# %% [markdown]
# # requirements

# %%
# module reloading script, fetches updates to ml4fmri package
import sys, importlib
from pathlib import Path

PKG = "ml4fmri"
# adjust as needed; this assumes your repo root is the CWD and sources are in ../src
SRC = Path().joinpath("../src").resolve()

def _ensure_src_on_path():
    p = str(SRC)
    if p not in sys.path:
        sys.path.insert(0, p)

def fresh_import_ml4fmri():
    """
    Remove any cached ml4fmri modules and import from SRC.
    Returns the ml4fmri module and (if available) meanMLP class.
    """
    _ensure_src_on_path()

    # purge previous imports so code changes take effect
    to_delete = [k for k in list(sys.modules) if k == PKG or k.startswith(PKG + ".")]
    for k in to_delete:
        del sys.modules[k]

    importlib.invalidate_caches()

    ml4fmri = __import__(PKG)
    meanMLP = None
    try:
        from ml4fmri.models import meanMLP 
    except Exception as e:
        print("Note: could not import meanMLP yet:", e)

    try:
        import inspect
        print("ml4fmri imported from:", Path(inspect.getfile(ml4fmri)).parent)
    except Exception:
        pass
    print("ml4fmri ready")
    return ml4fmri

# --- first import (or manual reload later) ---
ml4fmri = fresh_import_ml4fmri()

# get sample data for experiments
from abide import load_data as load_abide
from cobre import load_data as load_cobre

data, labels = load_abide()
data.shape, labels.shape

# data, labels = data[:100], labels[:100]
# Out:
# ml4fmri imported from: /Users/ppopov1/meanMLP/src/ml4fmri
# ml4fmri ready
# ((569, 140, 53), (569,))

# %% [markdown]
# # test cvbench

# %%
ml4fmri = fresh_import_ml4fmri()
from ml4fmri import cvbench # runs CV experiments with implemented models on the given data
report = cvbench(data, labels, n_folds=10)
report.plot_scores()
# Out:
# cvbench INFO: Running models: ['LR', 'meanMLP', 'MILC', 'Transformer', 'meanTransformer', 'BNT', 'BrainNetCNN', 'LSTM', 'meanLSTM']
# cvbench INFO: Using device: mps
# cvbench INFO: Training model: LR
# cvbench.LR INFO: Fold 01/10: Train/Val/Test AUC 1.000/1.000/0.737: Time elapsed 0.12 s
# ml4fmri imported from: /Users/ppopov1/meanMLP/src/ml4fmri
# ml4fmri ready
# cvbench.LR INFO: Fold 02/10: Train/Val/Test AUC 1.000/1.000/0.692: Time elapsed 0.11 s
# cvbench.LR INFO: Fold 03/10: Train/Val/Test AUC 1.000/1.000/0.671: Time elapsed 0.11 s
# cvbench.LR INFO: Fold 04/10: Train/Val/Test AUC 1.000/1.000/0.681: Time elapsed 0.11 s
# cvbench.LR INFO: Fold 05/10: Train/Val/Test AUC 1.000/1.000/0.742: Time elapsed 0.11 s
# cvbench.LR INFO: Fold 06/10: Train/Val/Test AUC 1.000/1.000/0.751: Time elapsed 0.11 s
# cvbench.LR INFO: Fold 07/10: Train/Val/Test AUC 1.000/1.000/0.646: Time elapsed 0.10 s
# cvbench.LR INFO: Fold 08/10: Train/Val/Test AUC 1.000/1.000/0.715: Time elapsed 0.11 s
# cvbench.LR INFO: Fold 09/10: Train/Val/Test AUC 1.000/1.000/0.776: Time elapsed 0.10 s
# cvbench.LR INFO: Fold 10/10: Train/Val/Test AUC 1.000/1.000/0.812: Time elapsed 0.11 s
# cvbench INFO: Training model: meanMLP
# cvbench.meanMLP INFO: Fold 01/10: Train/Val/Test AUC 0.982/0.720/0.847: Time elapsed 2.98 s
# cvbench.meanMLP INFO: Fold 02/10: Train/Val/Test AUC 0.937/0.738/0.643: Time elapsed 2.52 s
# cvbench.meanMLP INFO: Fold 03/10: Train/Val/Test AUC 0.974/0.784/0.707: Time elapsed 2.68 s
# cvbench.meanMLP INFO: Fold 04/10: Train/Val/Test AUC 0.985/0.784/0.748: Time elapsed 3.23 s
# cvbench.meanMLP INFO: Fold 05/10: Train/Val/Test AUC 0.987/0.762/0.768: Time elapsed 3.22 s
# cvbench.meanMLP INFO: Fold 06/10: Train/Val/Test AUC 0.960/0.716/0.758: Time elapsed 2.69 s
# cvbench.meanMLP INFO: Fold 07/10: Train/Val/Test AUC 0.985/0.731/0.636: Time elapsed 3.44 s
# cvbench.meanMLP INFO: Fold 08/10: Train/Val/Test AUC 0.937/0.740/0.795: Time elapsed 2.54 s
# cvbench.meanMLP INFO: Fold 09/10: Train/Val/Test AUC 0.955/0.799/0.821: Time elapsed 2.84 s
# cvbench.meanMLP INFO: Fold 10/10: Train/Val/Test AUC 0.953/0.731/0.822: Time elapsed 2.60 s
# cvbench INFO: Training model: MILC
# cvbench.MILC INFO: Fold 01/10: Train/Val/Test AUC 0.928/0.532/0.568: Time elapsed 4.92 s
# cvbench.MILC INFO: Fold 02/10: Train/Val/Test AUC 0.971/0.625/0.645: Time elapsed 5.16 s
# cvbench.MILC INFO: Fold 03/10: Train/Val/Test AUC 0.957/0.595/0.623: Time elapsed 4.87 s
# cvbench.MILC INFO: Fold 04/10: Train/Val/Test AUC 0.960/0.583/0.551: Time elapsed 4.67 s
# cvbench.MILC INFO: Fold 05/10: Train/Val/Test AUC 0.911/0.439/0.643: Time elapsed 4.30 s
# cvbench.MILC INFO: Fold 06/10: Train/Val/Test AUC 0.946/0.519/0.604: Time elapsed 4.42 s
# cvbench.MILC INFO: Fold 07/10: Train/Val/Test AUC 0.940/0.391/0.599: Time elapsed 4.19 s
# cvbench.MILC INFO: Fold 08/10: Train/Val/Test AUC 0.976/0.563/0.489: Time elapsed 4.65 s
# cvbench.MILC INFO: Fold 09/10: Train/Val/Test AUC 0.958/0.587/0.653: Time elapsed 4.74 s
# cvbench.MILC INFO: Fold 10/10: Train/Val/Test AUC 0.927/0.540/0.565: Time elapsed 4.41 s
# cvbench INFO: Training model: Transformer
# cvbench.Transformer INFO: Fold 01/10: Train/Val/Test AUC 0.573/0.489/0.632: Time elapsed 9.21 s
# cvbench.Transformer INFO: Fold 02/10: Train/Val/Test AUC 0.628/0.624/0.533: Time elapsed 9.22 s
# cvbench.Transformer INFO: Fold 03/10: Train/Val/Test AUC 0.685/0.623/0.660: Time elapsed 10.73 s
# cvbench.Transformer INFO: Fold 04/10: Train/Val/Test AUC 0.582/0.601/0.670: Time elapsed 9.68 s
# cvbench.Transformer INFO: Fold 05/10: Train/Val/Test AUC 0.594/0.582/0.548: Time elapsed 12.57 s
# cvbench.Transformer INFO: Fold 06/10: Train/Val/Test AUC 0.505/0.508/0.573: Time elapsed 10.36 s
# cvbench.Transformer INFO: Fold 07/10: Train/Val/Test AUC 0.512/0.576/0.550: Time elapsed 8.10 s
# cvbench.Transformer INFO: Fold 08/10: Train/Val/Test AUC 0.631/0.565/0.556: Time elapsed 11.85 s
# cvbench.Transformer INFO: Fold 09/10: Train/Val/Test AUC 0.724/0.635/0.618: Time elapsed 10.87 s
# cvbench.Transformer INFO: Fold 10/10: Train/Val/Test AUC 0.478/0.494/0.683: Time elapsed 10.84 s
# cvbench INFO: Training model: meanTransformer
# cvbench.meanTransformer INFO: Fold 01/10: Train/Val/Test AUC 0.718/0.641/0.759: Time elapsed 26.64 s
# cvbench.meanTransformer INFO: Fold 02/10: Train/Val/Test AUC 0.576/0.622/0.465: Time elapsed 30.16 s
# cvbench.meanTransformer INFO: Fold 03/10: Train/Val/Test AUC 0.700/0.684/0.412: Time elapsed 16.78 s
# cvbench.meanTransformer INFO: Fold 04/10: Train/Val/Test AUC 0.463/0.577/0.473: Time elapsed 10.96 s
# cvbench.meanTransformer INFO: Fold 05/10: Train/Val/Test AUC 0.733/0.719/0.641: Time elapsed 36.79 s
# cvbench.meanTransformer INFO: Fold 06/10: Train/Val/Test AUC 0.471/0.538/0.610: Time elapsed 15.62 s
# cvbench.meanTransformer INFO: Fold 07/10: Train/Val/Test AUC 0.458/0.536/0.600: Time elapsed 9.65 s
# cvbench.meanTransformer INFO: Fold 08/10: Train/Val/Test AUC 0.477/0.481/0.701: Time elapsed 9.67 s
# cvbench.meanTransformer INFO: Fold 09/10: Train/Val/Test AUC 0.710/0.643/0.573: Time elapsed 17.89 s
# cvbench.meanTransformer INFO: Fold 10/10: Train/Val/Test AUC 0.778/0.628/0.676: Time elapsed 18.94 s
# cvbench INFO: Training model: BNT
# cvbench.BNT INFO: Fold 01/10: Train/Val/Test AUC 0.884/0.660/0.844: Time elapsed 4.82 s
# cvbench.BNT INFO: Fold 02/10: Train/Val/Test AUC 0.883/0.663/0.664: Time elapsed 4.06 s
# cvbench.BNT INFO: Fold 03/10: Train/Val/Test AUC 0.975/0.817/0.696: Time elapsed 4.60 s
# cvbench.BNT INFO: Fold 04/10: Train/Val/Test AUC 0.950/0.769/0.774: Time elapsed 4.82 s
# cvbench.BNT INFO: Fold 05/10: Train/Val/Test AUC 0.951/0.800/0.710: Time elapsed 4.33 s
# cvbench.BNT INFO: Fold 06/10: Train/Val/Test AUC 0.924/0.676/0.757: Time elapsed 4.26 s
# cvbench.BNT INFO: Fold 07/10: Train/Val/Test AUC 0.913/0.634/0.647: Time elapsed 4.30 s
# cvbench.BNT INFO: Fold 08/10: Train/Val/Test AUC 0.942/0.744/0.742: Time elapsed 4.71 s
# cvbench.BNT INFO: Fold 09/10: Train/Val/Test AUC 0.954/0.802/0.786: Time elapsed 4.82 s
# cvbench.BNT INFO: Fold 10/10: Train/Val/Test AUC 0.906/0.714/0.840: Time elapsed 4.47 s
# cvbench INFO: Training model: BrainNetCNN
# cvbench.BrainNetCNN INFO: Fold 01/10: Train/Val/Test AUC 0.784/0.663/0.798: Time elapsed 10.48 s
# cvbench.BrainNetCNN INFO: Fold 02/10: Train/Val/Test AUC 0.922/0.679/0.573: Time elapsed 12.30 s
# cvbench.BrainNetCNN INFO: Fold 03/10: Train/Val/Test AUC 0.925/0.772/0.723: Time elapsed 11.77 s
# cvbench.BrainNetCNN INFO: Fold 04/10: Train/Val/Test AUC 0.867/0.744/0.680: Time elapsed 10.22 s
# cvbench.BrainNetCNN INFO: Fold 05/10: Train/Val/Test AUC 0.757/0.642/0.718: Time elapsed 10.43 s
# cvbench.BrainNetCNN INFO: Fold 06/10: Train/Val/Test AUC 0.696/0.664/0.693: Time elapsed 10.22 s
# cvbench.BrainNetCNN INFO: Fold 07/10: Train/Val/Test AUC 0.812/0.581/0.688: Time elapsed 9.29 s
# cvbench.BrainNetCNN INFO: Fold 08/10: Train/Val/Test AUC 0.901/0.743/0.720: Time elapsed 11.76 s
# cvbench.BrainNetCNN INFO: Fold 09/10: Train/Val/Test AUC 0.841/0.789/0.686: Time elapsed 12.01 s
# cvbench.BrainNetCNN INFO: Fold 10/10: Train/Val/Test AUC 0.795/0.696/0.790: Time elapsed 11.46 s
# cvbench INFO: Training model: LSTM
# cvbench.LSTM INFO: Fold 01/10: Train/Val/Test AUC 0.767/0.592/0.524: Time elapsed 26.37 s
# cvbench.LSTM INFO: Fold 02/10: Train/Val/Test AUC 0.754/0.542/0.635: Time elapsed 18.76 s
# cvbench.LSTM INFO: Fold 03/10: Train/Val/Test AUC 0.704/0.508/0.666: Time elapsed 16.38 s
# cvbench.LSTM INFO: Fold 04/10: Train/Val/Test AUC 0.822/0.639/0.573: Time elapsed 32.16 s
# cvbench.LSTM INFO: Fold 05/10: Train/Val/Test AUC 0.763/0.630/0.408: Time elapsed 21.79 s
# cvbench.LSTM INFO: Fold 06/10: Train/Val/Test AUC 0.560/0.478/0.475: Time elapsed 10.06 s
# cvbench.LSTM INFO: Fold 07/10: Train/Val/Test AUC 0.810/0.612/0.537: Time elapsed 30.99 s
# cvbench.LSTM INFO: Fold 08/10: Train/Val/Test AUC 0.854/0.651/0.505: Time elapsed 32.86 s
# cvbench.LSTM INFO: Fold 09/10: Train/Val/Test AUC 0.780/0.600/0.615: Time elapsed 23.97 s
# cvbench.LSTM INFO: Fold 10/10: Train/Val/Test AUC 0.756/0.552/0.572: Time elapsed 27.95 s
# cvbench INFO: Training model: meanLSTM
# cvbench.meanLSTM INFO: Fold 01/10: Train/Val/Test AUC 0.841/0.625/0.728: Time elapsed 34.43 s
# cvbench.meanLSTM INFO: Fold 02/10: Train/Val/Test AUC 0.822/0.635/0.596: Time elapsed 29.58 s
# cvbench.meanLSTM INFO: Fold 03/10: Train/Val/Test AUC 0.802/0.659/0.596: Time elapsed 39.04 s
# cvbench.meanLSTM INFO: Fold 04/10: Train/Val/Test AUC 0.807/0.687/0.550: Time elapsed 33.40 s
# cvbench.meanLSTM INFO: Fold 05/10: Train/Val/Test AUC 0.826/0.637/0.680: Time elapsed 30.13 s
# cvbench.meanLSTM INFO: Fold 06/10: Train/Val/Test AUC 0.816/0.578/0.694: Time elapsed 26.49 s
# cvbench.meanLSTM INFO: Fold 07/10: Train/Val/Test AUC 0.806/0.546/0.652: Time elapsed 24.64 s
# cvbench.meanLSTM INFO: Fold 08/10: Train/Val/Test AUC 0.809/0.652/0.625: Time elapsed 34.68 s
# cvbench.meanLSTM INFO: Fold 09/10: Train/Val/Test AUC 0.862/0.692/0.634: Time elapsed 32.33 s
# cvbench.meanLSTM INFO: Fold 10/10: Train/Val/Test AUC 0.848/0.592/0.841: Time elapsed 30.81 s

# %%
train_df = report.get_train_dataframe()
test_df = report.get_test_dataframe()
meta = report.meta

# %%
import json

train_path = "cvbench_train.csv"
test_path = "cvbench_test.csv"
meta_path = "cvbench_meta.json"

train_df.to_csv(train_path, index=False)
test_df.to_csv(test_path, index=False)
with open(meta_path, "w") as f:
    json.dump(meta, f)

# %%
import pandas as pd
import json

# Load the train and test dataframes
train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)

# Load the meta data
with open(meta_path, "r") as f:
    meta = json.load(f)

# %%
ml4fmri = fresh_import_ml4fmri()
from ml4fmri import Report # runs CV experiments with implemented models on the given data
report = Report(train_df, test_df, meta)
report.plot_training_curves()
# Out:
# ml4fmri imported from: /Users/ppopov1/meanMLP/src/ml4fmri
# ml4fmri ready
# (None, None)
